# %% [markdown]
# # 02 - Data Pipeline
# Load and preprocess the `unsloth/qwen3_5_vision` dataset into model-ready batches.

# %%
from datasets import load_dataset
from torchvision import transforms

dataset = load_dataset('unsloth/qwen3_5_vision')
dataset

# %%
# TODO: Replace with your tokenizer/processor
def preprocess_example(example):
    # Expected fields: image, prompt/input text, target response
    return example

processed = dataset.map(preprocess_example)
processed
